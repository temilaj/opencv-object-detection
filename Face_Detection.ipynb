# %% [markdown]
# ### Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#render matplotlib images in the same window
# %matplotlib inline

# %% [markdown]
# ### Create Classifier

# %%
face_classifer = cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')

# %% [markdown]
# ### Open Image

# %%
image = cv2.imread('Images/eye_face.jpg')
fix_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(fix_image)

# %% [markdown]
# ### Detect Faces

# %%
faces = face_classifer.detectMultiScale(image, 1.3, 5)

# %% [markdown]
# ### No Faces Detected

# %%
# # TODO FiX THIS
# if faces is ():
#     print('No Faces found')

# %% [markdown]
# ### It's a kind of Magic

# %%
def detect_face(img):
    face_rects = face_classifer.detectMultiScale(img, 1.3, 5)
    
    for (x,y,w,h) in face_rects:
        cv2.rectangle(img, 
                     (x,y),
                     (x+w, y+h),
                     (255, 0,0),
                     10)
    return img

# %%
result = detect_face(fix_image)
plt.imshow(result)
